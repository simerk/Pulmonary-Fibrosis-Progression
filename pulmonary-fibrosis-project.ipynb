# %% [markdown]
# # Imports

# %%
# !pip install efficientnet
# !pip install opencv-python
# !pip install tensorflow

# %%
import os
import cv2
import pydicom
import pandas as pd
import numpy as np 
import tensorflow as tf 
import matplotlib.pyplot as plt 
import random
from tqdm.notebook import tqdm 
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_absolute_error
from tensorflow_addons.optimizers import RectifiedAdam
from tensorflow.keras import Model
import tensorflow.keras.backend as K
import tensorflow.keras.layers as L
import tensorflow.keras.models as M
from tensorflow.keras.optimizers import Nadam
import seaborn as sns
from PIL import Image

def seed_everything(seed=2020):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    
seed_everything(42)

# %%
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)

# %%
train = pd.read_csv('../input/osic-pulmonary-fibrosis-progression/train.csv')

# %% [markdown]
# # EfficientNets

# %%
def get_tab(df):
    vector = [(df.Age.values[0] - 30) / 30] 
    
    if df.Sex.values[0] == 'male':
       vector.append(0)
    else:
       vector.append(1)
    
    if df.SmokingStatus.values[0] == 'Never smoked':
        vector.extend([0,0])
    elif df.SmokingStatus.values[0] == 'Ex-smoker':
        vector.extend([1,1])
    elif df.SmokingStatus.values[0] == 'Currently smokes':
        vector.extend([0,1])
    else:
        vector.extend([1,0])
    return np.array(vector)

# %%
A = {} 
TAB = {} 
P = [] 
for i, p in tqdm(enumerate(train.Patient.unique())):
    sub = train.loc[train.Patient == p, :] 
    fvc = sub.FVC.values
    weeks = sub.Weeks.values
    c = np.vstack([weeks, np.ones(len(weeks))]).T
    a, b = np.linalg.lstsq(c, fvc)[0]
    
    A[p] = a
    TAB[p] = get_tab(sub)
    P.append(p)

# %% [markdown]
# ## CNN for coeff prediction

# %%
def get_img(path):
    d = pydicom.dcmread(path)
    return cv2.resize(d.pixel_array / 2**11, (512, 512))

# %%
from tensorflow.keras.utils import Sequence

class IGenerator(Sequence):
    BAD_ID = ['ID00011637202177653955184', 'ID00052637202186188008618']
    def __init__(self, keys, a, tab, batch_size=32):
        self.keys = [k for k in keys if k not in self.BAD_ID]
        self.a = a
        self.tab = tab
        self.batch_size = batch_size
        
        self.train_data = {}
        for p in train.Patient.values:
            self.train_data[p] = os.listdir(f'../input/osic-pulmonary-fibrosis-progression/train/{p}/')
    
    def __len__(self):
        return 1000
    
    def __getitem__(self, idx):
        x = []
        a, tab = [], [] 
        keys = np.random.choice(self.keys, size = self.batch_size)
        for k in keys:
            try:
                i = np.random.choice(self.train_data[k], size=1)[0]
                img = get_img(f'../input/osic-pulmonary-fibrosis-progression/train/{k}/{i}')
                x.append(img)
                a.append(self.a[k])
                tab.append(self.tab[k])
            except:
                print(k, i)
       
        x,a,tab = np.array(x), np.array(a), np.array(tab)
        x = np.expand_dims(x, axis=-1)
        return [x, tab] , a

# %%
from tensorflow.keras.layers import (
    Dense, Dropout, Activation, Flatten, Input, BatchNormalization, GlobalAveragePooling2D, Add, Conv2D, AveragePooling2D, 
    LeakyReLU, Concatenate 
)
import efficientnet.tfkeras as efn

def get_efficientnet(model, shape):
    models_dict = {
        'b0': efn.EfficientNetB0(input_shape=shape,weights=None,include_top=False),
        'b1': efn.EfficientNetB1(input_shape=shape,weights=None,include_top=False),
        'b2': efn.EfficientNetB2(input_shape=shape,weights=None,include_top=False),
        'b3': efn.EfficientNetB3(input_shape=shape,weights=None,include_top=False),
        'b4': efn.EfficientNetB4(input_shape=shape,weights=None,include_top=False),
        'b5': efn.EfficientNetB5(input_shape=shape,weights=None,include_top=False),
        'b6': efn.EfficientNetB6(input_shape=shape,weights=None,include_top=False),
        'b7': efn.EfficientNetB7(input_shape=shape,weights=None,include_top=False)
    }
    return models_dict[model]

def build_model(shape=(512, 512, 1), model_class=None):
    inp = Input(shape=shape)
    base = get_efficientnet(model_class, shape)
    x = base(inp)
    x = GlobalAveragePooling2D()(x)
    inp2 = Input(shape=(4,))
    x2 = tf.keras.layers.GaussianNoise(0.2)(inp2)
    x = Concatenate()([x, x2]) 
    x = Dropout(0.5)(x) 
    x = Dense(1)(x)
    model = Model([inp, inp2] , x)
    
    weights = [w for w in os.listdir('../input/osic-model-weights') if model_class in w][0]
#     model.load_weights('../input/osic-model-weights/' + weights)
    model.load_weights('../input/effnet-b5-30epochs-1/effnet_30.h5')
    return model

model_classes = ['b5'] #['b0','b1','b2','b3',b4','b5','b6','b7']
models = [build_model(shape=(512, 512, 1), model_class=m) for m in model_classes]
print('Number of models: ' + str(len(models)))

# %%
from sklearn.model_selection import train_test_split 

tr_p, vl_p = train_test_split(P, 
                              shuffle=True, 
                              train_size= 1)

# %%
def score(fvc_true, fvc_pred, sigma):
    sigma_clip = np.maximum(sigma, 70)
    delta = np.abs(fvc_true - fvc_pred)
    delta = np.minimum(delta, 1000)
    sq2 = np.sqrt(2)
    metric = (delta / sigma_clip)*sq2 + np.log(sigma_clip* sq2)
    return np.mean(metric)

# %%
subs = []
for model in models:

    q = 0.5

    sub = pd.read_csv('../input/osic-pulmonary-fibrosis-progression/sample_submission.csv') 
    test = pd.read_csv('../input/osic-pulmonary-fibrosis-progression/test.csv') 
    A_test, B_test, P_test,W, FVC= {}, {}, {},{},{} 
    STD, WEEK = {}, {} 
    for p in test.Patient.unique():
        x = [] 
        tab = [] 
        ldir = os.listdir(f'../input/osic-pulmonary-fibrosis-progression/test/{p}/')
        for i in ldir:
            if int(i[:-4]) / len(ldir) < 1.1 and int(i[:-4]) / len(ldir) > -0.1:
                x.append(get_img(f'../input/osic-pulmonary-fibrosis-progression/test/{p}/{i}')) 
                tab.append(get_tab(test.loc[test.Patient == p, :])) 
        if len(x) <= 1:
            continue
        tab = np.array(tab) 

        x = np.expand_dims(x, axis=-1) 
        _a = model.predict([x, tab]) 
        a = np.quantile(_a, q)
        A_test[p] = a
        B_test[p] = test.FVC.values[test.Patient == p] - a*test.Weeks.values[test.Patient == p]
        P_test[p] = test.Percent.values[test.Patient == p] 
        WEEK[p] = test.Weeks.values[test.Patient == p]

    for k in sub.Patient_Week.values:
        p, w = k.split('_')
        w = int(w) 

        fvc = A_test[p] * w + B_test[p]
        sub.loc[sub.Patient_Week == k, 'FVC'] = fvc
        sub.loc[sub.Patient_Week == k, 'Confidence'] = (
            P_test[p] - A_test[p] * abs(WEEK[p] - w) 
    ) 

    _sub = sub[["Patient_Week","FVC","Confidence"]].copy()
    subs.append(_sub)

# %%
subs[0]

# %%
N = len(subs)
sub = subs[0].copy() # ref
sub["FVC"] = 0
sub["Confidence"] = 0
for i in range(N):
    sub["FVC"] += subs[0]["FVC"] * (1/N)
    sub["Confidence"] += subs[0]["Confidence"] * (1/N)

# %%
sub.head()

# %%
sub[["Patient_Week","FVC","Confidence"]].to_csv("submission_img.csv", index=False)

# %%
img_sub = sub[["Patient_Week","FVC","Confidence"]].copy()

# %%
img_sub

# %% [markdown]
# # Quantile-Regression

# %%
ROOT = "../input/osic-pulmonary-fibrosis-progression"
BATCH_SIZE=128

tr = pd.read_csv(f"{ROOT}/train.csv")
tr.drop_duplicates(keep=False, inplace=True, subset=['Patient','Weeks'])
chunk = pd.read_csv(f"{ROOT}/test.csv")

print("add infos")
sub = pd.read_csv(f"{ROOT}/sample_submission.csv")
sub['Patient'] = sub['Patient_Week'].apply(lambda x:x.split('_')[0])
sub['Weeks'] = sub['Patient_Week'].apply(lambda x: int(x.split('_')[-1]))
sub =  sub[['Patient','Weeks','Confidence','Patient_Week']]
sub = sub.merge(chunk.drop('Weeks', axis=1), on="Patient")

# %%
tr['WHERE'] = 'train'
chunk['WHERE'] = 'val'
sub['WHERE'] = 'test'
data = tr.append([chunk, sub])

# %%
print(tr.shape, chunk.shape, sub.shape, data.shape)
print(tr.Patient.nunique(), chunk.Patient.nunique(), sub.Patient.nunique(), 
      data.Patient.nunique())
#

# %%
data['min_week'] = data['Weeks']
data.loc[data.WHERE=='test','min_week'] = np.nan
data['min_week'] = data.groupby('Patient')['min_week'].transform('min')

# %%
base = data.loc[data.Weeks == data.min_week]
base = base[['Patient','FVC']].copy()
base.columns = ['Patient','min_FVC']
base['nb'] = 1
base['nb'] = base.groupby('Patient')['nb'].transform('cumsum')
base = base[base.nb==1]
base.drop('nb', axis=1, inplace=True)

# %%
data = data.merge(base, on='Patient', how='left')
data['base_week'] = data['Weeks'] - data['min_week']
del base

# %%
data

# %%
COLS = ['Sex','SmokingStatus'] #,'Age'
FE = []
for col in COLS:
    for mod in data[col].unique():
        FE.append(mod)
        data[mod] = (data[col] == mod).astype(int)

# %%
#
data['age'] = (data['Age'] - data['Age'].min() ) / ( data['Age'].max() - data['Age'].min() )
data['BASE'] = (data['min_FVC'] - data['min_FVC'].min() ) / ( data['min_FVC'].max() - data['min_FVC'].min() )
data['week'] = (data['base_week'] - data['base_week'].min() ) / ( data['base_week'].max() - data['base_week'].min() )
data['percent'] = (data['Percent'] - data['Percent'].min() ) / ( data['Percent'].max() - data['Percent'].min() )
FE += ['age','week','BASE']

# %%
tr = data.loc[data.WHERE=='train']
chunk = data.loc[data.WHERE=='val']
sub = data.loc[data.WHERE=='test']
del data

# %%
tr.shape, chunk.shape, sub.shape

# %%
C1, C2 = tf.constant(70, dtype='float32'), tf.constant(1000, dtype="float32")

def score(y_true, y_pred):
    tf.dtypes.cast(y_true, tf.float32)
    tf.dtypes.cast(y_pred, tf.float32)
    sigma = y_pred[:, 2] - y_pred[:, 0]
    fvc_pred = y_pred[:, 1]
    
    #sigma_clip = sigma + C1
    sigma_clip = tf.maximum(sigma, C1)
    delta = tf.abs(y_true[:, 0] - fvc_pred)
    delta = tf.minimum(delta, C2)
    sq2 = tf.sqrt( tf.dtypes.cast(2, dtype=tf.float32) )
    metric = (delta / sigma_clip)*sq2 + tf.math.log(sigma_clip* sq2)
    return K.mean(metric)

def qloss(y_true, y_pred):
    # Pinball loss for multiple quantiles
    qs = [0.2, 0.50, 0.8]
    q = tf.constant(np.array([qs]), dtype=tf.float32)
    e = y_true - y_pred
    v = tf.maximum(q*e, (q-1)*e)
    return K.mean(v)

def mloss(_lambda):
    def loss(y_true, y_pred):
        return _lambda * qloss(y_true, y_pred) + (1 - _lambda)*score(y_true, y_pred)
    return loss

def make_model(nh):
    z = L.Input((nh,), name="Patient")
    x = L.Dense(100, activation="relu", name="d1")(z)
    x = L.Dense(100, activation="relu", name="d2")(x)
    #x = L.Dense(100, activation="relu", name="d3")(x)
    p1 = L.Dense(3, activation="linear", name="p1")(x)
    p2 = L.Dense(3, activation="relu", name="p2")(x)
    preds = L.Lambda(lambda x: x[0] + tf.cumsum(x[1], axis=1), 
                     name="preds")([p1, p2])
    
    model = M.Model(z, preds, name="CNN")
    #model.compile(loss=qloss, optimizer="adam", metrics=[score])
    model.compile(loss=mloss(0.8), optimizer=tf.keras.optimizers.Adam(lr=0.09, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.01, amsgrad=False), metrics=[score])
    return model

# %%
y = tr['FVC'].values
z = tr[FE].values
ze = sub[FE].values
nh = z.shape[1]
pe = np.zeros((ze.shape[0], 3))
pred = np.zeros((z.shape[0], 3))

# %%
net = make_model(nh)
print(net.summary())
print(net.count_params())

# %%
NFOLD = 2 # originally 5
kf = KFold(n_splits=NFOLD)

# %%
# %%time
cnt = 0
EPOCHS = 700
for tr_idx, val_idx in kf.split(z):
    cnt += 1
    print(f"FOLD {cnt}")
    net = make_model(nh)
    net.fit(z[tr_idx], y[tr_idx], batch_size=BATCH_SIZE, epochs=EPOCHS, 
            validation_data=(z[val_idx], y[val_idx])) #
    print("train", net.evaluate(z[tr_idx], y[tr_idx], verbose=0, batch_size=BATCH_SIZE))
    print("val", net.evaluate(z[val_idx], y[val_idx], verbose=0, batch_size=BATCH_SIZE))
    print("predict val...")
    pred[val_idx] = net.predict(z[val_idx], batch_size=BATCH_SIZE, verbose=0)
    print("predict test...")
    pe += net.predict(ze, batch_size=BATCH_SIZE, verbose=0) / NFOLD
# Out:
# Epoch 181/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.6050 - score: 6.6241 - val_loss: 59.2473 - val_score: 6.8361
# Epoch 182/700
# 6/6 [==============================] - 0s 8ms/step - loss: 47.1087 - score: 6.6346 - val_loss: 55.9360 - val_score: 6.7904
# Epoch 183/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.7994 - score: 6.6284 - val_loss: 56.4506 - val_score: 6.7939
# Epoch 184/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.7668 - score: 6.6220 - val_loss: 57.5717 - val_score: 6.8061
# Epoch 185/700
# 6/6 [==============================] - 0s 10ms/step - loss: 46.7367 - score: 6.6257 - val_loss: 58.7963 - val_score: 6.8309
# Epoch 186/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.6669 - score: 6.6215 - val_loss: 57.1497 - val_score: 6.8074
# Epoch 187/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.9662 - score: 6.6247 - val_loss: 56.4328 - val_score: 6.7908
# Epoch 188/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3982 - score: 6.6162 - val_loss: 57.4568 - val_score: 6.8070
# Epoch 189/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.5083 - score: 6.6258 - val_loss: 55.8956 - val_score: 6.7855
# Epoch 190/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3910 - score: 6.6229 - val_loss: 58.6290 - val_score: 6.8224
# Epoch 191/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.4308 - score: 6.6119 - val_loss: 56.1501 - val_score: 6.7870
# Epoch 192/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.9754 - score: 6.6233 - val_loss: 57.2512 - val_score: 6.8123
# Epoch 193/700
# 6/6 [==============================] - 0s 8ms/step - loss: 47.1355 - score: 6.6338 - val_loss: 61.1657 - val_score: 6.8854
# Epoch 194/700
# 6/6 [==============================] - 0s 8ms/step - loss: 47.4483 - score: 6.6501 - val_loss: 57.6663 - val_score: 6.8162
# Epoch 195/700
# 6/6 [==============================] - 0s 10ms/step - loss: 46.7200 - score: 6.6255 - val_loss: 56.2436 - val_score: 6.7924
# Epoch 196/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.7726 - score: 6.6271 - val_loss: 57.9435 - val_score: 6.8147
# Epoch 197/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.3684 - score: 6.6149 - val_loss: 56.5805 - val_score: 6.7915
# Epoch 198/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.6898 - score: 6.6147 - val_loss: 56.6805 - val_score: 6.7934
# Epoch 199/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.6689 - score: 6.6229 - val_loss: 59.4987 - val_score: 6.8388
# Epoch 200/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4975 - score: 6.6132 - val_loss: 56.8547 - val_score: 6.7957
# Epoch 201/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4744 - score: 6.6123 - val_loss: 56.8540 - val_score: 6.7971
# Epoch 202/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4807 - score: 6.6173 - val_loss: 58.4751 - val_score: 6.8241
# Epoch 203/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4364 - score: 6.6115 - val_loss: 55.8897 - val_score: 6.7856
# Epoch 204/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.4297 - score: 6.6298 - val_loss: 60.1445 - val_score: 6.8536
# Epoch 205/700
# 6/6 [==============================] - 0s 10ms/step - loss: 46.9372 - score: 6.6340 - val_loss: 55.8394 - val_score: 6.7867
# Epoch 206/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.6319 - score: 6.6264 - val_loss: 58.3500 - val_score: 6.8202
# Epoch 207/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4749 - score: 6.6158 - val_loss: 57.2615 - val_score: 6.8027
# Epoch 208/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.2995 - score: 6.6103 - val_loss: 56.6287 - val_score: 6.7966
# Epoch 209/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.3645 - score: 6.6163 - val_loss: 57.7683 - val_score: 6.8080
# Epoch 210/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.6119 - score: 6.6165 - val_loss: 56.0673 - val_score: 6.7902
# Epoch 211/700
# 6/6 [==============================] - 0s 9ms/step - loss: 47.0802 - score: 6.6385 - val_loss: 61.0634 - val_score: 6.8695
# Epoch 212/700
# 6/6 [==============================] - 0s 8ms/step - loss: 47.5525 - score: 6.6411 - val_loss: 56.7873 - val_score: 6.8039
# Epoch 213/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.9027 - score: 6.6239 - val_loss: 56.3441 - val_score: 6.7914
# Epoch 214/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.9378 - score: 6.6305 - val_loss: 60.6677 - val_score: 6.8623
# Epoch 215/700
# 6/6 [==============================] - 0s 10ms/step - loss: 47.2120 - score: 6.6343 - val_loss: 55.5642 - val_score: 6.7875
# Epoch 216/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.5702 - score: 6.6271 - val_loss: 57.9084 - val_score: 6.8191
# Epoch 217/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.7702 - score: 6.6361 - val_loss: 56.9380 - val_score: 6.7995
# Epoch 218/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.7983 - score: 6.6200 - val_loss: 56.2359 - val_score: 6.7879
# Epoch 219/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.8147 - score: 6.6224 - val_loss: 56.4245 - val_score: 6.7946
# Epoch 220/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3826 - score: 6.6181 - val_loss: 57.6547 - val_score: 6.8104
# Epoch 221/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3976 - score: 6.6092 - val_loss: 56.2834 - val_score: 6.7873
# Epoch 222/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4069 - score: 6.6156 - val_loss: 57.2600 - val_score: 6.8023
# Epoch 223/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4464 - score: 6.6232 - val_loss: 59.0281 - val_score: 6.8302
# Epoch 224/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4771 - score: 6.6167 - val_loss: 55.9257 - val_score: 6.7921
# Epoch 225/700
# 6/6 [==============================] - 0s 15ms/step - loss: 47.5709 - score: 6.6508 - val_loss: 62.4469 - val_score: 6.9047
# Epoch 226/700
# 6/6 [==============================] - 0s 18ms/step - loss: 47.3622 - score: 6.6390 - val_loss: 56.3307 - val_score: 6.7894
# Epoch 227/700
# 6/6 [==============================] - 0s 12ms/step - loss: 46.8913 - score: 6.6154 - val_loss: 56.7247 - val_score: 6.7990
# Epoch 228/700
# 6/6 [==============================] - 0s 15ms/step - loss: 46.7634 - score: 6.6309 - val_loss: 58.9682 - val_score: 6.8365
# Epoch 229/700
# 6/6 [==============================] - 0s 11ms/step - loss: 46.9268 - score: 6.6251 - val_loss: 56.3503 - val_score: 6.7960
# Epoch 230/700
# 6/6 [==============================] - 0s 12ms/step - loss: 46.7376 - score: 6.6388 - val_loss: 60.7160 - val_score: 6.8635
# Epoch 231/700
# 6/6 [==============================] - 0s 12ms/step - loss: 46.7821 - score: 6.6198 - val_loss: 56.4433 - val_score: 6.7905
# Epoch 232/700
# 6/6 [==============================] - 0s 13ms/step - loss: 46.5388 - score: 6.6107 - val_loss: 56.6857 - val_score: 6.7933
# Epoch 233/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2752 - score: 6.6158 - val_loss: 57.3038 - val_score: 6.8082
# Epoch 234/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.5921 - score: 6.6243 - val_loss: 59.1196 - val_score: 6.8352
# Epoch 235/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.9333 - score: 6.6193 - val_loss: 55.6827 - val_score: 6.7802
# Epoch 236/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4460 - score: 6.6155 - val_loss: 59.5523 - val_score: 6.8394
# Epoch 237/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.9257 - score: 6.6159 - val_loss: 56.0752 - val_score: 6.7808
# Epoch 238/700
# 6/6 [==============================] - 0s 11ms/step - loss: 46.3747 - score: 6.6039 - val_loss: 57.5368 - val_score: 6.8066
# Epoch 239/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4196 - score: 6.6200 - val_loss: 58.3999 - val_score: 6.8300
# Epoch 240/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.5468 - score: 6.6276 - val_loss: 56.1737 - val_score: 6.7926
# Epoch 241/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.6210 - score: 6.6193 - val_loss: 56.4224 - val_score: 6.7892
# Epoch 242/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3487 - score: 6.6126 - val_loss: 57.3182 - val_score: 6.8023
# Epoch 243/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3260 - score: 6.6052 - val_loss: 56.8702 - val_score: 6.7969
# Epoch 244/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.6314 - score: 6.6216 - val_loss: 58.8814 - val_score: 6.8351
# Epoch 245/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.8519 - score: 6.6212 - val_loss: 55.5515 - val_score: 6.7828
# Epoch 246/700
# 6/6 [==============================] - 0s 10ms/step - loss: 47.5780 - score: 6.6510 - val_loss: 61.3799 - val_score: 6.8821
# Epoch 247/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4837 - score: 6.6283 - val_loss: 55.8439 - val_score: 6.7950
# Epoch 248/700
# 6/6 [==============================] - 0s 8ms/step - loss: 47.0060 - score: 6.6333 - val_loss: 60.1354 - val_score: 6.8486
# Epoch 249/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.5831 - score: 6.6181 - val_loss: 56.5938 - val_score: 6.7921
# Epoch 250/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3095 - score: 6.6104 - val_loss: 58.2906 - val_score: 6.8236
# Epoch 251/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.5053 - score: 6.6130 - val_loss: 56.0925 - val_score: 6.7834
# Epoch 252/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2873 - score: 6.6050 - val_loss: 58.5524 - val_score: 6.8170
# Epoch 253/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4604 - score: 6.6159 - val_loss: 57.6258 - val_score: 6.8116
# Epoch 254/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2624 - score: 6.6194 - val_loss: 57.7399 - val_score: 6.8222
# Epoch 255/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.3639 - score: 6.6197 - val_loss: 58.1942 - val_score: 6.8157
# Epoch 256/700
# 6/6 [==============================] - 0s 10ms/step - loss: 46.5202 - score: 6.6126 - val_loss: 55.7701 - val_score: 6.7853
# Epoch 257/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.7043 - score: 6.6363 - val_loss: 58.5944 - val_score: 6.8270
# Epoch 258/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2608 - score: 6.6120 - val_loss: 56.6499 - val_score: 6.7883
# Epoch 259/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3728 - score: 6.6116 - val_loss: 57.0398 - val_score: 6.7993
# Epoch 260/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1965 - score: 6.6112 - val_loss: 57.4858 - val_score: 6.8071
# Epoch 261/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4190 - score: 6.6132 - val_loss: 57.2604 - val_score: 6.8079
# Epoch 262/700
# 6/6 [==============================] - 0s 10ms/step - loss: 46.8363 - score: 6.6303 - val_loss: 59.1849 - val_score: 6.8458
# Epoch 263/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.8695 - score: 6.6249 - val_loss: 55.7873 - val_score: 6.7902
# Epoch 264/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.9970 - score: 6.6418 - val_loss: 61.0632 - val_score: 6.8716
# Epoch 265/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.6492 - score: 6.6259 - val_loss: 55.8817 - val_score: 6.7888
# Epoch 266/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.4830 - score: 6.6197 - val_loss: 58.4742 - val_score: 6.8229
# Epoch 267/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.8842 - score: 6.6174 - val_loss: 58.3371 - val_score: 6.8218
# Epoch 268/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.6938 - score: 6.6171 - val_loss: 56.8282 - val_score: 6.8033
# Epoch 269/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3182 - score: 6.6171 - val_loss: 57.0631 - val_score: 6.8032
# Epoch 270/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4710 - score: 6.6246 - val_loss: 58.9138 - val_score: 6.8306
# Epoch 271/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4760 - score: 6.6153 - val_loss: 56.5567 - val_score: 6.7959
# Epoch 272/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3962 - score: 6.6158 - val_loss: 57.2108 - val_score: 6.8086
# Epoch 273/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4739 - score: 6.6235 - val_loss: 58.2603 - val_score: 6.8227
# Epoch 274/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4311 - score: 6.6169 - val_loss: 56.8884 - val_score: 6.8020
# Epoch 275/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3627 - score: 6.6203 - val_loss: 59.4925 - val_score: 6.8329
# Epoch 276/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.5444 - score: 6.6094 - val_loss: 56.4547 - val_score: 6.7882
# Epoch 277/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.7350 - score: 6.6180 - val_loss: 57.1866 - val_score: 6.8110
# Epoch 278/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4071 - score: 6.6272 - val_loss: 57.4896 - val_score: 6.8119
# Epoch 279/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2116 - score: 6.6170 - val_loss: 56.9551 - val_score: 6.7977
# Epoch 280/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3299 - score: 6.6119 - val_loss: 57.2317 - val_score: 6.8028
# Epoch 281/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3747 - score: 6.6167 - val_loss: 57.1724 - val_score: 6.8089
# Epoch 282/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2540 - score: 6.6235 - val_loss: 57.4917 - val_score: 6.8083
# Epoch 283/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2951 - score: 6.6113 - val_loss: 56.9085 - val_score: 6.7971
# Epoch 284/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1756 - score: 6.6066 - val_loss: 57.9651 - val_score: 6.8126
# Epoch 285/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.1725 - score: 6.6043 - val_loss: 56.4984 - val_score: 6.7933
# Epoch 286/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.4540 - score: 6.6127 - val_loss: 59.3179 - val_score: 6.8416
# Epoch 287/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4006 - score: 6.6200 - val_loss: 56.2552 - val_score: 6.7973
# Epoch 288/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1294 - score: 6.6166 - val_loss: 58.8775 - val_score: 6.8295
# Epoch 289/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4491 - score: 6.6179 - val_loss: 57.4235 - val_score: 6.8024
# Epoch 290/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3060 - score: 6.6098 - val_loss: 56.8707 - val_score: 6.7959
# Epoch 291/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2314 - score: 6.6151 - val_loss: 57.4584 - val_score: 6.8056
# Epoch 292/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1485 - score: 6.6064 - val_loss: 57.4063 - val_score: 6.8068
# Epoch 293/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2099 - score: 6.6135 - val_loss: 57.1415 - val_score: 6.8087
# Epoch 294/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3730 - score: 6.6157 - val_loss: 56.8496 - val_score: 6.7990
# Epoch 295/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2860 - score: 6.6169 - val_loss: 57.7600 - val_score: 6.8106
# Epoch 296/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.1726 - score: 6.6083 - val_loss: 57.1682 - val_score: 6.8015
# Epoch 297/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2331 - score: 6.6118 - val_loss: 56.2588 - val_score: 6.7877
# Epoch 298/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.5491 - score: 6.6188 - val_loss: 58.1336 - val_score: 6.8165
# Epoch 299/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1530 - score: 6.6107 - val_loss: 56.8031 - val_score: 6.8012
# Epoch 300/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1360 - score: 6.6101 - val_loss: 57.8726 - val_score: 6.8146
# Epoch 301/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2058 - score: 6.6100 - val_loss: 57.4038 - val_score: 6.8051
# Epoch 302/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4273 - score: 6.6103 - val_loss: 57.1903 - val_score: 6.8029
# Epoch 303/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3438 - score: 6.6211 - val_loss: 58.0031 - val_score: 6.8199
# Epoch 304/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2161 - score: 6.6137 - val_loss: 57.5294 - val_score: 6.8050
# Epoch 305/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2188 - score: 6.6077 - val_loss: 57.4977 - val_score: 6.8032
# Epoch 306/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.1854 - score: 6.6096 - val_loss: 57.4760 - val_score: 6.8059
# Epoch 307/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3371 - score: 6.6120 - val_loss: 57.3653 - val_score: 6.8079
# Epoch 308/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.5180 - score: 6.6272 - val_loss: 58.3657 - val_score: 6.8318
# Epoch 309/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3010 - score: 6.6158 - val_loss: 56.9660 - val_score: 6.8045
# Epoch 310/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2191 - score: 6.6123 - val_loss: 57.7762 - val_score: 6.8106
# Epoch 311/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3616 - score: 6.6150 - val_loss: 57.5576 - val_score: 6.8087
# Epoch 312/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1123 - score: 6.6120 - val_loss: 56.3594 - val_score: 6.7891
# Epoch 313/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2896 - score: 6.6082 - val_loss: 58.2856 - val_score: 6.8144
# Epoch 314/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2564 - score: 6.6103 - val_loss: 57.3969 - val_score: 6.8103
# Epoch 315/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1880 - score: 6.6121 - val_loss: 58.2584 - val_score: 6.8241
# Epoch 316/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.2992 - score: 6.6165 - val_loss: 56.2635 - val_score: 6.7898
# Epoch 317/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1851 - score: 6.6152 - val_loss: 58.7131 - val_score: 6.8272
# Epoch 318/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1542 - score: 6.6124 - val_loss: 56.6492 - val_score: 6.7941
# Epoch 319/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1579 - score: 6.6157 - val_loss: 57.7439 - val_score: 6.8124
# Epoch 320/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3215 - score: 6.6151 - val_loss: 57.7579 - val_score: 6.8093
# Epoch 321/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1431 - score: 6.6048 - val_loss: 57.1826 - val_score: 6.8037
# Epoch 322/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2109 - score: 6.6201 - val_loss: 57.2598 - val_score: 6.8156
# Epoch 323/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0783 - score: 6.6173 - val_loss: 57.2337 - val_score: 6.8043
# Epoch 324/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0863 - score: 6.6066 - val_loss: 57.3379 - val_score: 6.7991
# Epoch 325/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1870 - score: 6.6007 - val_loss: 57.9901 - val_score: 6.8066
# Epoch 326/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.0971 - score: 6.6050 - val_loss: 56.3851 - val_score: 6.7888
# Epoch 327/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1373 - score: 6.6086 - val_loss: 58.9197 - val_score: 6.8348
# Epoch 328/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1616 - score: 6.6157 - val_loss: 56.5054 - val_score: 6.7994
# Epoch 329/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1601 - score: 6.6144 - val_loss: 58.4772 - val_score: 6.8253
# Epoch 330/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.5486 - score: 6.6163 - val_loss: 56.9623 - val_score: 6.8012
# Epoch 331/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2957 - score: 6.6169 - val_loss: 57.5436 - val_score: 6.8132
# Epoch 332/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.5812 - score: 6.6252 - val_loss: 58.5215 - val_score: 6.8268
# Epoch 333/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.9491 - score: 6.6195 - val_loss: 56.0272 - val_score: 6.7937
# Epoch 334/700
# 6/6 [==============================] - 0s 8ms/step - loss: 47.0935 - score: 6.6400 - val_loss: 59.8629 - val_score: 6.8597
# Epoch 335/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.7219 - score: 6.6226 - val_loss: 55.7169 - val_score: 6.7824
# Epoch 336/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.0977 - score: 6.6052 - val_loss: 59.7233 - val_score: 6.8403
# Epoch 337/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4160 - score: 6.6037 - val_loss: 55.7294 - val_score: 6.7811
# Epoch 338/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.6346 - score: 6.6180 - val_loss: 58.3121 - val_score: 6.8201
# Epoch 339/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9690 - score: 6.6041 - val_loss: 56.7699 - val_score: 6.7967
# Epoch 340/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1322 - score: 6.6099 - val_loss: 59.0887 - val_score: 6.8336
# Epoch 341/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2354 - score: 6.6078 - val_loss: 56.1999 - val_score: 6.7889
# Epoch 342/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3315 - score: 6.6162 - val_loss: 58.6724 - val_score: 6.8261
# Epoch 343/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3421 - score: 6.6084 - val_loss: 56.6362 - val_score: 6.7927
# Epoch 344/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.7826 - score: 6.6198 - val_loss: 58.2377 - val_score: 6.8233
# Epoch 345/700
# 6/6 [==============================] - 0s 8ms/step - loss: 47.0085 - score: 6.6380 - val_loss: 58.7072 - val_score: 6.8291
# Epoch 346/700
# 6/6 [==============================] - 0s 10ms/step - loss: 46.4399 - score: 6.6149 - val_loss: 56.5097 - val_score: 6.7978
# Epoch 347/700
# 6/6 [==============================] - 0s 10ms/step - loss: 46.0845 - score: 6.6124 - val_loss: 58.9628 - val_score: 6.8378
# Epoch 348/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.4378 - score: 6.6142 - val_loss: 56.3098 - val_score: 6.7955
# Epoch 349/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.7026 - score: 6.6276 - val_loss: 58.5307 - val_score: 6.8278
# Epoch 350/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2831 - score: 6.6162 - val_loss: 56.4352 - val_score: 6.7956
# Epoch 351/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9939 - score: 6.6110 - val_loss: 59.4764 - val_score: 6.8363
# Epoch 352/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3994 - score: 6.6091 - val_loss: 56.4961 - val_score: 6.7953
# Epoch 353/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1970 - score: 6.6200 - val_loss: 58.5789 - val_score: 6.8306
# Epoch 354/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1015 - score: 6.6139 - val_loss: 56.7745 - val_score: 6.7955
# Epoch 355/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2127 - score: 6.6097 - val_loss: 58.1309 - val_score: 6.8137
# Epoch 356/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.1210 - score: 6.6089 - val_loss: 57.2280 - val_score: 6.8005
# Epoch 357/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0458 - score: 6.6081 - val_loss: 58.2084 - val_score: 6.8251
# Epoch 358/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1588 - score: 6.6083 - val_loss: 57.1495 - val_score: 6.8046
# Epoch 359/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0756 - score: 6.6080 - val_loss: 57.5217 - val_score: 6.8064
# Epoch 360/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0916 - score: 6.6015 - val_loss: 57.8329 - val_score: 6.8116
# Epoch 361/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0537 - score: 6.6116 - val_loss: 57.0444 - val_score: 6.8037
# Epoch 362/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1755 - score: 6.6087 - val_loss: 57.8020 - val_score: 6.8118
# Epoch 363/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1129 - score: 6.6126 - val_loss: 57.0472 - val_score: 6.8018
# Epoch 364/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9680 - score: 6.6075 - val_loss: 57.9308 - val_score: 6.8137
# Epoch 365/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1161 - score: 6.6109 - val_loss: 56.7861 - val_score: 6.8008
# Epoch 366/700
# 6/6 [==============================] - 0s 9ms/step - loss: 45.9983 - score: 6.6062 - val_loss: 58.0103 - val_score: 6.8114
# Epoch 367/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0667 - score: 6.5981 - val_loss: 57.5966 - val_score: 6.8057
# Epoch 368/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2035 - score: 6.6077 - val_loss: 57.2594 - val_score: 6.8021
# Epoch 369/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.0504 - score: 6.6056 - val_loss: 57.6274 - val_score: 6.8121
# Epoch 370/700
# 6/6 [==============================] - 0s 10ms/step - loss: 46.0083 - score: 6.6129 - val_loss: 57.0626 - val_score: 6.8037
# Epoch 371/700
# 6/6 [==============================] - 0s 20ms/step - loss: 46.0459 - score: 6.6150 - val_loss: 56.9622 - val_score: 6.8015
# Epoch 372/700
# 6/6 [==============================] - 0s 13ms/step - loss: 46.0765 - score: 6.6051 - val_loss: 57.6448 - val_score: 6.8096
# Epoch 373/700
# 6/6 [==============================] - 0s 10ms/step - loss: 46.1095 - score: 6.6053 - val_loss: 57.7072 - val_score: 6.8105
# Epoch 374/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2923 - score: 6.6066 - val_loss: 56.8187 - val_score: 6.8015
# Epoch 375/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1978 - score: 6.6198 - val_loss: 58.2931 - val_score: 6.8194
# Epoch 376/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.3783 - score: 6.6106 - val_loss: 56.3258 - val_score: 6.7938
# Epoch 377/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4385 - score: 6.6267 - val_loss: 59.8507 - val_score: 6.8493
# Epoch 378/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4339 - score: 6.6051 - val_loss: 56.0127 - val_score: 6.7832
# Epoch 379/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1525 - score: 6.6090 - val_loss: 58.8866 - val_score: 6.8288
# Epoch 380/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1457 - score: 6.5978 - val_loss: 56.6141 - val_score: 6.7919
# Epoch 381/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2971 - score: 6.6137 - val_loss: 59.4046 - val_score: 6.8408
# Epoch 382/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4311 - score: 6.6138 - val_loss: 56.4199 - val_score: 6.7984
# Epoch 383/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2692 - score: 6.6185 - val_loss: 58.6928 - val_score: 6.8293
# Epoch 384/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9966 - score: 6.6026 - val_loss: 56.8563 - val_score: 6.7936
# Epoch 385/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3615 - score: 6.6042 - val_loss: 57.0738 - val_score: 6.8018
# Epoch 386/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.4253 - score: 6.6169 - val_loss: 58.6077 - val_score: 6.8323
# Epoch 387/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1378 - score: 6.6131 - val_loss: 56.6794 - val_score: 6.8058
# Epoch 388/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9958 - score: 6.6113 - val_loss: 57.8186 - val_score: 6.8118
# Epoch 389/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0431 - score: 6.6039 - val_loss: 56.9978 - val_score: 6.7948
# Epoch 390/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0187 - score: 6.6010 - val_loss: 58.2354 - val_score: 6.8164
# Epoch 391/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9591 - score: 6.6007 - val_loss: 56.7819 - val_score: 6.7984
# Epoch 392/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9799 - score: 6.6060 - val_loss: 58.1989 - val_score: 6.8210
# Epoch 393/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0254 - score: 6.6067 - val_loss: 56.9996 - val_score: 6.8028
# Epoch 394/700
# 6/6 [==============================] - 0s 9ms/step - loss: 45.9968 - score: 6.6126 - val_loss: 57.7597 - val_score: 6.8142
# Epoch 395/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0832 - score: 6.6045 - val_loss: 56.8826 - val_score: 6.7949
# Epoch 396/700
# 6/6 [==============================] - 0s 10ms/step - loss: 46.1494 - score: 6.6052 - val_loss: 59.3224 - val_score: 6.8392
# Epoch 397/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2602 - score: 6.6145 - val_loss: 57.1740 - val_score: 6.8074
# Epoch 398/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1378 - score: 6.6113 - val_loss: 57.8874 - val_score: 6.8185
# Epoch 399/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.6586 - score: 6.6218 - val_loss: 57.8117 - val_score: 6.8104
# Epoch 400/700
# 6/6 [==============================] - 0s 10ms/step - loss: 46.4052 - score: 6.6070 - val_loss: 56.7040 - val_score: 6.7984
# Epoch 401/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.4322 - score: 6.6275 - val_loss: 59.3696 - val_score: 6.8363
# Epoch 402/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.8727 - score: 6.6162 - val_loss: 56.0718 - val_score: 6.7941
# Epoch 403/700
# 6/6 [==============================] - 0s 9ms/step - loss: 47.1027 - score: 6.6375 - val_loss: 59.4142 - val_score: 6.8519
# Epoch 404/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.8004 - score: 6.6279 - val_loss: 56.3102 - val_score: 6.8025
# Epoch 405/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.1493 - score: 6.6201 - val_loss: 59.3173 - val_score: 6.8417
# Epoch 406/700
# 6/6 [==============================] - 1s 154ms/step - loss: 46.1578 - score: 6.6055 - val_loss: 56.9242 - val_score: 6.7995
# Epoch 407/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0407 - score: 6.6076 - val_loss: 58.1438 - val_score: 6.8183
# Epoch 408/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9565 - score: 6.5965 - val_loss: 56.9356 - val_score: 6.7957
# Epoch 409/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9910 - score: 6.6014 - val_loss: 57.6900 - val_score: 6.8089
# Epoch 410/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0287 - score: 6.6042 - val_loss: 57.8226 - val_score: 6.8127
# Epoch 411/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9282 - score: 6.6034 - val_loss: 57.4118 - val_score: 6.8049
# Epoch 412/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9138 - score: 6.6026 - val_loss: 57.4671 - val_score: 6.8082
# Epoch 413/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9291 - score: 6.6028 - val_loss: 57.3288 - val_score: 6.8025
# Epoch 414/700
# 6/6 [==============================] - 0s 10ms/step - loss: 46.3051 - score: 6.6140 - val_loss: 58.5343 - val_score: 6.8198
# Epoch 415/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2106 - score: 6.5974 - val_loss: 57.0145 - val_score: 6.8013
# Epoch 416/700
# 6/6 [==============================] - 0s 10ms/step - loss: 46.0244 - score: 6.6100 - val_loss: 57.7932 - val_score: 6.8160
# Epoch 417/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0051 - score: 6.6031 - val_loss: 57.5328 - val_score: 6.8051
# Epoch 418/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9800 - score: 6.6002 - val_loss: 57.0369 - val_score: 6.8034
# Epoch 419/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0556 - score: 6.6145 - val_loss: 58.3773 - val_score: 6.8274
# Epoch 420/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9965 - score: 6.6047 - val_loss: 57.6667 - val_score: 6.8113
# Epoch 421/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9800 - score: 6.6034 - val_loss: 56.9653 - val_score: 6.7984
# Epoch 422/700
# 6/6 [==============================] - 0s 10ms/step - loss: 46.0438 - score: 6.5975 - val_loss: 57.6012 - val_score: 6.8097
# Epoch 423/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1048 - score: 6.6059 - val_loss: 56.5414 - val_score: 6.7959
# Epoch 424/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9793 - score: 6.6057 - val_loss: 58.1878 - val_score: 6.8217
# Epoch 425/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.7858 - score: 6.6210 - val_loss: 56.6059 - val_score: 6.7925
# Epoch 426/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.5657 - score: 6.6083 - val_loss: 58.1430 - val_score: 6.8200
# Epoch 427/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1778 - score: 6.6142 - val_loss: 56.6543 - val_score: 6.7972
# Epoch 428/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9650 - score: 6.6061 - val_loss: 58.2082 - val_score: 6.8239
# Epoch 429/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8315 - score: 6.6088 - val_loss: 56.8567 - val_score: 6.8024
# Epoch 430/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0219 - score: 6.6022 - val_loss: 58.0041 - val_score: 6.8081
# Epoch 431/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8862 - score: 6.5905 - val_loss: 56.9181 - val_score: 6.7928
# Epoch 432/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8215 - score: 6.5947 - val_loss: 57.4673 - val_score: 6.8068
# Epoch 433/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8912 - score: 6.6079 - val_loss: 57.0853 - val_score: 6.8088
# Epoch 434/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9410 - score: 6.6125 - val_loss: 57.3778 - val_score: 6.8086
# Epoch 435/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0250 - score: 6.6008 - val_loss: 56.9784 - val_score: 6.7976
# Epoch 436/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.0240 - score: 6.6000 - val_loss: 56.9343 - val_score: 6.7982
# Epoch 437/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4779 - score: 6.6126 - val_loss: 58.2941 - val_score: 6.8170
# Epoch 438/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.0884 - score: 6.6068 - val_loss: 56.5509 - val_score: 6.7956
# Epoch 439/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1405 - score: 6.6066 - val_loss: 58.0571 - val_score: 6.8167
# Epoch 440/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8915 - score: 6.6049 - val_loss: 56.9452 - val_score: 6.7999
# Epoch 441/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8710 - score: 6.5946 - val_loss: 57.9876 - val_score: 6.8158
# Epoch 442/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.7992 - score: 6.6022 - val_loss: 56.5159 - val_score: 6.7979
# Epoch 443/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9256 - score: 6.6071 - val_loss: 58.5491 - val_score: 6.8272
# Epoch 444/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8538 - score: 6.5992 - val_loss: 56.7650 - val_score: 6.7936
# Epoch 445/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0135 - score: 6.6021 - val_loss: 56.9690 - val_score: 6.7989
# Epoch 446/700
# 6/6 [==============================] - 0s 9ms/step - loss: 45.8761 - score: 6.6042 - val_loss: 58.0773 - val_score: 6.8183
# Epoch 447/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2165 - score: 6.6078 - val_loss: 56.3082 - val_score: 6.7969
# Epoch 448/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.8792 - score: 6.6325 - val_loss: 58.1123 - val_score: 6.8240
# Epoch 449/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.7315 - score: 6.6112 - val_loss: 56.8367 - val_score: 6.8035
# Epoch 450/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4574 - score: 6.6202 - val_loss: 57.9984 - val_score: 6.8216
# Epoch 451/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9259 - score: 6.6050 - val_loss: 57.6841 - val_score: 6.8090
# Epoch 452/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0104 - score: 6.5933 - val_loss: 56.8725 - val_score: 6.7932
# Epoch 453/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8366 - score: 6.5972 - val_loss: 57.0086 - val_score: 6.7973
# Epoch 454/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8191 - score: 6.5990 - val_loss: 58.2258 - val_score: 6.8179
# Epoch 455/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8816 - score: 6.5984 - val_loss: 56.9758 - val_score: 6.8025
# Epoch 456/700
# 6/6 [==============================] - 0s 9ms/step - loss: 45.8986 - score: 6.6050 - val_loss: 58.2193 - val_score: 6.8215
# Epoch 457/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2126 - score: 6.5991 - val_loss: 56.5412 - val_score: 6.7928
# Epoch 458/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4154 - score: 6.6181 - val_loss: 58.1184 - val_score: 6.8190
# Epoch 459/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.7016 - score: 6.6099 - val_loss: 56.5940 - val_score: 6.7986
# Epoch 460/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.5379 - score: 6.6249 - val_loss: 58.0234 - val_score: 6.8219
# Epoch 461/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.6621 - score: 6.6151 - val_loss: 56.5837 - val_score: 6.7984
# Epoch 462/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0143 - score: 6.6130 - val_loss: 57.2975 - val_score: 6.8095
# Epoch 463/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8859 - score: 6.6001 - val_loss: 57.3240 - val_score: 6.8034
# Epoch 464/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2422 - score: 6.6082 - val_loss: 58.3797 - val_score: 6.8192
# Epoch 465/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0037 - score: 6.5947 - val_loss: 57.3816 - val_score: 6.8071
# Epoch 466/700
# 6/6 [==============================] - 0s 9ms/step - loss: 45.9578 - score: 6.6098 - val_loss: 57.5237 - val_score: 6.8099
# Epoch 467/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9484 - score: 6.5976 - val_loss: 57.6603 - val_score: 6.8140
# Epoch 468/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.7460 - score: 6.5982 - val_loss: 56.7302 - val_score: 6.7990
# Epoch 469/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8907 - score: 6.6026 - val_loss: 57.6432 - val_score: 6.8092
# Epoch 470/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8210 - score: 6.5935 - val_loss: 57.4622 - val_score: 6.8068
# Epoch 471/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8514 - score: 6.5893 - val_loss: 57.8493 - val_score: 6.8123
# Epoch 472/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8552 - score: 6.6004 - val_loss: 57.5050 - val_score: 6.8107
# Epoch 473/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.7898 - score: 6.6051 - val_loss: 57.5625 - val_score: 6.8117
# Epoch 474/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.7951 - score: 6.6053 - val_loss: 57.4563 - val_score: 6.8055
# Epoch 475/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8389 - score: 6.5953 - val_loss: 57.6416 - val_score: 6.8092
# Epoch 476/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.2214 - score: 6.6007 - val_loss: 57.2501 - val_score: 6.8002
# Epoch 477/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4591 - score: 6.6001 - val_loss: 57.7186 - val_score: 6.8150
# Epoch 478/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.6541 - score: 6.6325 - val_loss: 56.9173 - val_score: 6.8062
# Epoch 479/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3138 - score: 6.6131 - val_loss: 57.5787 - val_score: 6.8175
# Epoch 480/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.3306 - score: 6.6200 - val_loss: 57.0259 - val_score: 6.8032
# Epoch 481/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9908 - score: 6.5968 - val_loss: 57.3318 - val_score: 6.8044
# Epoch 482/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.0969 - score: 6.6040 - val_loss: 57.9257 - val_score: 6.8141
# Epoch 483/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8274 - score: 6.5915 - val_loss: 58.0626 - val_score: 6.8198
# Epoch 484/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8654 - score: 6.6049 - val_loss: 56.4773 - val_score: 6.7988
# Epoch 485/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8434 - score: 6.6076 - val_loss: 57.1972 - val_score: 6.8021
# Epoch 486/700
# 6/6 [==============================] - 0s 9ms/step - loss: 45.8833 - score: 6.5963 - val_loss: 57.1755 - val_score: 6.7975
# Epoch 487/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8374 - score: 6.5900 - val_loss: 57.5653 - val_score: 6.8084
# Epoch 488/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0338 - score: 6.6044 - val_loss: 58.1514 - val_score: 6.8233
# Epoch 489/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8445 - score: 6.6045 - val_loss: 57.3095 - val_score: 6.8065
# Epoch 490/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8402 - score: 6.5969 - val_loss: 57.2605 - val_score: 6.8021
# Epoch 491/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.7247 - score: 6.5962 - val_loss: 57.0235 - val_score: 6.7983
# Epoch 492/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.7411 - score: 6.5926 - val_loss: 57.1145 - val_score: 6.8006
# Epoch 493/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9232 - score: 6.5976 - val_loss: 57.0135 - val_score: 6.8040
# Epoch 494/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9705 - score: 6.6067 - val_loss: 57.8158 - val_score: 6.8138
# Epoch 495/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9064 - score: 6.6005 - val_loss: 56.7896 - val_score: 6.8007
# Epoch 496/700
# 6/6 [==============================] - 0s 9ms/step - loss: 46.1341 - score: 6.6108 - val_loss: 57.9567 - val_score: 6.8173
# Epoch 497/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.7772 - score: 6.5940 - val_loss: 57.4362 - val_score: 6.8052
# Epoch 498/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.7605 - score: 6.5937 - val_loss: 56.6783 - val_score: 6.7947
# Epoch 499/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.7637 - score: 6.5980 - val_loss: 57.2576 - val_score: 6.8038
# Epoch 500/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.7672 - score: 6.5958 - val_loss: 57.6115 - val_score: 6.8093
# Epoch 501/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8515 - score: 6.6028 - val_loss: 57.5507 - val_score: 6.8065
# Epoch 502/700
# 6/6 [==============================] - 0s 9ms/step - loss: 45.7410 - score: 6.5972 - val_loss: 58.0562 - val_score: 6.8144
# Epoch 503/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8004 - score: 6.5991 - val_loss: 57.2262 - val_score: 6.8045
# Epoch 504/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.7468 - score: 6.6027 - val_loss: 57.0724 - val_score: 6.8006
# Epoch 505/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.7994 - score: 6.5903 - val_loss: 57.1929 - val_score: 6.8005
# Epoch 506/700
# 6/6 [==============================] - 0s 9ms/step - loss: 45.7274 - score: 6.5898 - val_loss: 57.1157 - val_score: 6.7995
# Epoch 507/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9578 - score: 6.5957 - val_loss: 57.8177 - val_score: 6.8133
# Epoch 508/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.7382 - score: 6.6028 - val_loss: 56.7620 - val_score: 6.8033
# Epoch 509/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0209 - score: 6.6084 - val_loss: 57.1866 - val_score: 6.8065
# Epoch 510/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.2402 - score: 6.6177 - val_loss: 57.7507 - val_score: 6.8111
# Epoch 511/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1765 - score: 6.6055 - val_loss: 57.3257 - val_score: 6.8090
# Epoch 512/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.4760 - score: 6.6262 - val_loss: 57.0835 - val_score: 6.8070
# Epoch 513/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8164 - score: 6.6003 - val_loss: 58.3442 - val_score: 6.8243
# Epoch 514/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1821 - score: 6.6086 - val_loss: 56.9885 - val_score: 6.7974
# Epoch 515/700
# 6/6 [==============================] - 0s 9ms/step - loss: 45.9105 - score: 6.5887 - val_loss: 59.0913 - val_score: 6.8309
# Epoch 516/700
# 6/6 [==============================] - 0s 11ms/step - loss: 45.7669 - score: 6.5984 - val_loss: 56.1219 - val_score: 6.7915
# Epoch 517/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.1372 - score: 6.6052 - val_loss: 59.5507 - val_score: 6.8440
# Epoch 518/700
# 6/6 [==============================] - 0s 8ms/step - loss: 46.0705 - score: 6.6073 - val_loss: 56.7215 - val_score: 6.7992
# Epoch 519/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8011 - score: 6.5964 - val_loss: 57.8286 - val_score: 6.8118
# Epoch 520/700
# 6/6 [==============================] - 0s 9ms/step - loss: 45.7845 - score: 6.5923 - val_loss: 57.2607 - val_score: 6.8021
# Epoch 521/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.6678 - score: 6.5894 - val_loss: 57.4469 - val_score: 6.8057
# Epoch 522/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8103 - score: 6.5974 - val_loss: 56.5044 - val_score: 6.7938
# Epoch 523/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.9363 - score: 6.6037 - val_loss: 57.8737 - val_score: 6.8124
# Epoch 524/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.7738 - score: 6.5940 - val_loss: 57.0905 - val_score: 6.8014
# Epoch 525/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.8474 - score: 6.5932 - val_loss: 58.2647 - val_score: 6.8205
# Epoch 526/700
# 6/6 [==============================] - 0s 9ms/step - loss: 45.7021 - score: 6.6001 - val_loss: 56.5317 - val_score: 6.7948
# Epoch 527/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.7520 - score: 6.5989 - val_loss: 57.8163 - val_score: 6.8115
# Epoch 528/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.7623 - score: 6.5887 - val_loss: 57.3368 - val_score: 6.8015
# Epoch 529/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.6657 - score: 6.5871 - val_loss: 57.2345 - val_score: 6.8026
# Epoch 530/700
# 6/6 [==============================] - 0s 8ms/step - loss: 45.6556 - score: 6.5944 - val_loss: 57.0780 - val_score: 6.8011
# Epoch 531/700
# ...
# Epoch 586/700
# 6/6 [==============================] - 0s 12ms/step - loss: 50.2225 - score: 6.6494 - val_loss: 50.9789 - val_score: 6.6986
# Epoch 587/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.1758 - score: 6.6524 - val_loss: 49.9130 - val_score: 6.6749
# Epoch 588/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.3261 - score: 6.6504 - val_loss: 51.1073 - val_score: 6.7003
# Epoch 589/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.3287 - score: 6.6460 - val_loss: 50.0001 - val_score: 6.6736
# Epoch 590/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.3580 - score: 6.6461 - val_loss: 50.3118 - val_score: 6.6790
# Epoch 591/700
# 6/6 [==============================] - 0s 13ms/step - loss: 50.1815 - score: 6.6417 - val_loss: 50.2672 - val_score: 6.6807
# Epoch 592/700
# 6/6 [==============================] - 0s 11ms/step - loss: 50.4734 - score: 6.6584 - val_loss: 49.8509 - val_score: 6.6742
# Epoch 593/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.3161 - score: 6.6489 - val_loss: 51.1227 - val_score: 6.7008
# Epoch 594/700
# 6/6 [==============================] - 0s 10ms/step - loss: 50.3281 - score: 6.6473 - val_loss: 50.3715 - val_score: 6.6845
# Epoch 595/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.2074 - score: 6.6437 - val_loss: 50.4745 - val_score: 6.6877
# Epoch 596/700
# 6/6 [==============================] - 0s 10ms/step - loss: 50.2595 - score: 6.6512 - val_loss: 50.0545 - val_score: 6.6779
# Epoch 597/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.3275 - score: 6.6484 - val_loss: 50.3944 - val_score: 6.6814
# Epoch 598/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.1644 - score: 6.6469 - val_loss: 50.3843 - val_score: 6.6822
# Epoch 599/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.1319 - score: 6.6403 - val_loss: 50.1722 - val_score: 6.6797
# Epoch 600/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.2195 - score: 6.6386 - val_loss: 51.0121 - val_score: 6.7029
# Epoch 601/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.3565 - score: 6.6548 - val_loss: 49.8351 - val_score: 6.6738
# Epoch 602/700
# 6/6 [==============================] - 0s 10ms/step - loss: 50.3255 - score: 6.6545 - val_loss: 50.9737 - val_score: 6.6979
# Epoch 603/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.2107 - score: 6.6499 - val_loss: 50.0942 - val_score: 6.6764
# Epoch 604/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.0714 - score: 6.6377 - val_loss: 50.4701 - val_score: 6.6854
# Epoch 605/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.1222 - score: 6.6392 - val_loss: 50.2197 - val_score: 6.6803
# Epoch 606/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.3677 - score: 6.6464 - val_loss: 50.8167 - val_score: 6.6980
# Epoch 607/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.1609 - score: 6.6558 - val_loss: 50.0233 - val_score: 6.6793
# Epoch 608/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.1016 - score: 6.6474 - val_loss: 50.5220 - val_score: 6.6869
# Epoch 609/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0890 - score: 6.6378 - val_loss: 50.0407 - val_score: 6.6746
# Epoch 610/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0754 - score: 6.6369 - val_loss: 51.1295 - val_score: 6.6989
# Epoch 611/700
# 6/6 [==============================] - 0s 10ms/step - loss: 50.2997 - score: 6.6478 - val_loss: 49.8492 - val_score: 6.6722
# Epoch 612/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.2742 - score: 6.6471 - val_loss: 50.5941 - val_score: 6.6869
# Epoch 613/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.2309 - score: 6.6469 - val_loss: 50.0590 - val_score: 6.6765
# Epoch 614/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.2486 - score: 6.6486 - val_loss: 50.1980 - val_score: 6.6797
# Epoch 615/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.1964 - score: 6.6463 - val_loss: 50.6043 - val_score: 6.6909
# Epoch 616/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.1478 - score: 6.6493 - val_loss: 50.0567 - val_score: 6.6805
# Epoch 617/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.3238 - score: 6.6456 - val_loss: 51.2438 - val_score: 6.7058
# Epoch 618/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.4915 - score: 6.6542 - val_loss: 49.9555 - val_score: 6.6739
# Epoch 619/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.2919 - score: 6.6467 - val_loss: 50.6870 - val_score: 6.6885
# Epoch 620/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.1246 - score: 6.6452 - val_loss: 49.8448 - val_score: 6.6733
# Epoch 621/700
# 6/6 [==============================] - 0s 10ms/step - loss: 50.3140 - score: 6.6450 - val_loss: 50.5482 - val_score: 6.6902
# Epoch 622/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.0664 - score: 6.6460 - val_loss: 49.8266 - val_score: 6.6748
# Epoch 623/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.3633 - score: 6.6526 - val_loss: 50.7614 - val_score: 6.6960
# Epoch 624/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0091 - score: 6.6452 - val_loss: 49.9455 - val_score: 6.6762
# Epoch 625/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0405 - score: 6.6419 - val_loss: 50.7668 - val_score: 6.6949
# Epoch 626/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.1516 - score: 6.6382 - val_loss: 50.0074 - val_score: 6.6752
# Epoch 627/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.1407 - score: 6.6351 - val_loss: 50.4991 - val_score: 6.6837
# Epoch 628/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0392 - score: 6.6406 - val_loss: 50.0846 - val_score: 6.6768
# Epoch 629/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0391 - score: 6.6408 - val_loss: 50.5872 - val_score: 6.6884
# Epoch 630/700
# 6/6 [==============================] - 0s 10ms/step - loss: 50.2142 - score: 6.6379 - val_loss: 50.3752 - val_score: 6.6839
# Epoch 631/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.2352 - score: 6.6438 - val_loss: 50.1370 - val_score: 6.6774
# Epoch 632/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.3089 - score: 6.6469 - val_loss: 50.8931 - val_score: 6.6934
# Epoch 633/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.1431 - score: 6.6517 - val_loss: 50.2091 - val_score: 6.6795
# Epoch 634/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.2619 - score: 6.6438 - val_loss: 50.8635 - val_score: 6.6958
# Epoch 635/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.1813 - score: 6.6419 - val_loss: 50.0813 - val_score: 6.6760
# Epoch 636/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.6629 - score: 6.6542 - val_loss: 51.9505 - val_score: 6.7202
# Epoch 637/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.5575 - score: 6.6709 - val_loss: 49.7955 - val_score: 6.6762
# Epoch 638/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.6205 - score: 6.6668 - val_loss: 51.1549 - val_score: 6.7019
# Epoch 639/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0313 - score: 6.6391 - val_loss: 49.8691 - val_score: 6.6739
# Epoch 640/700
# 6/6 [==============================] - 0s 10ms/step - loss: 50.3916 - score: 6.6423 - val_loss: 51.9318 - val_score: 6.7178
# Epoch 641/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.4625 - score: 6.6566 - val_loss: 49.9781 - val_score: 6.6751
# Epoch 642/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.2347 - score: 6.6493 - val_loss: 50.7231 - val_score: 6.6863
# Epoch 643/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0357 - score: 6.6429 - val_loss: 50.1473 - val_score: 6.6769
# Epoch 644/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0773 - score: 6.6383 - val_loss: 50.5789 - val_score: 6.6901
# Epoch 645/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.2038 - score: 6.6476 - val_loss: 49.8965 - val_score: 6.6761
# Epoch 646/700
# 6/6 [==============================] - 0s 10ms/step - loss: 50.1079 - score: 6.6438 - val_loss: 50.6197 - val_score: 6.6906
# Epoch 647/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0991 - score: 6.6449 - val_loss: 50.4663 - val_score: 6.6852
# Epoch 648/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.2006 - score: 6.6419 - val_loss: 50.5362 - val_score: 6.6851
# Epoch 649/700
# 6/6 [==============================] - 0s 10ms/step - loss: 50.0244 - score: 6.6433 - val_loss: 50.5875 - val_score: 6.6861
# Epoch 650/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0435 - score: 6.6390 - val_loss: 50.5072 - val_score: 6.6856
# Epoch 651/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0322 - score: 6.6362 - val_loss: 50.5145 - val_score: 6.6864
# Epoch 652/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0308 - score: 6.6383 - val_loss: 50.1684 - val_score: 6.6795
# Epoch 653/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.1278 - score: 6.6429 - val_loss: 50.3208 - val_score: 6.6820
# Epoch 654/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.0517 - score: 6.6387 - val_loss: 50.0243 - val_score: 6.6750
# Epoch 655/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.0683 - score: 6.6396 - val_loss: 50.7154 - val_score: 6.6920
# Epoch 656/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0484 - score: 6.6441 - val_loss: 50.1825 - val_score: 6.6799
# Epoch 657/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0113 - score: 6.6355 - val_loss: 50.1640 - val_score: 6.6784
# Epoch 658/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.1024 - score: 6.6352 - val_loss: 50.7688 - val_score: 6.6923
# Epoch 659/700
# 6/6 [==============================] - 0s 10ms/step - loss: 50.0241 - score: 6.6382 - val_loss: 50.0337 - val_score: 6.6763
# Epoch 660/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0319 - score: 6.6467 - val_loss: 50.5861 - val_score: 6.6885
# Epoch 661/700
# 6/6 [==============================] - 0s 9ms/step - loss: 49.9717 - score: 6.6396 - val_loss: 50.0858 - val_score: 6.6761
# Epoch 662/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0867 - score: 6.6287 - val_loss: 50.8060 - val_score: 6.6957
# Epoch 663/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.2155 - score: 6.6329 - val_loss: 50.0150 - val_score: 6.6748
# Epoch 664/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0735 - score: 6.6475 - val_loss: 50.6708 - val_score: 6.6923
# Epoch 665/700
# 6/6 [==============================] - 0s 9ms/step - loss: 49.9972 - score: 6.6488 - val_loss: 50.1746 - val_score: 6.6796
# Epoch 666/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.2801 - score: 6.6410 - val_loss: 50.8128 - val_score: 6.6935
# Epoch 667/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.1733 - score: 6.6347 - val_loss: 50.3537 - val_score: 6.6851
# Epoch 668/700
# 6/6 [==============================] - 0s 10ms/step - loss: 50.0280 - score: 6.6452 - val_loss: 50.3589 - val_score: 6.6833
# Epoch 669/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.1756 - score: 6.6446 - val_loss: 50.5851 - val_score: 6.6874
# Epoch 670/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.0261 - score: 6.6341 - val_loss: 50.1960 - val_score: 6.6778
# Epoch 671/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.0040 - score: 6.6369 - val_loss: 50.3270 - val_score: 6.6805
# Epoch 672/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.0676 - score: 6.6437 - val_loss: 49.8367 - val_score: 6.6728
# Epoch 673/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.2385 - score: 6.6492 - val_loss: 51.3229 - val_score: 6.7101
# Epoch 674/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0613 - score: 6.6422 - val_loss: 50.0967 - val_score: 6.6800
# Epoch 675/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0816 - score: 6.6390 - val_loss: 50.7931 - val_score: 6.6928
# Epoch 676/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.0321 - score: 6.6428 - val_loss: 50.2997 - val_score: 6.6793
# Epoch 677/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.0100 - score: 6.6350 - val_loss: 50.5339 - val_score: 6.6845
# Epoch 678/700
# 6/6 [==============================] - 0s 10ms/step - loss: 50.0005 - score: 6.6281 - val_loss: 50.0666 - val_score: 6.6762
# Epoch 679/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.1248 - score: 6.6389 - val_loss: 50.7660 - val_score: 6.6948
# Epoch 680/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.2754 - score: 6.6534 - val_loss: 49.7262 - val_score: 6.6725
# Epoch 681/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.1344 - score: 6.6419 - val_loss: 51.4764 - val_score: 6.7109
# Epoch 682/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.1935 - score: 6.6485 - val_loss: 49.8705 - val_score: 6.6733
# Epoch 683/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.3330 - score: 6.6485 - val_loss: 51.6201 - val_score: 6.7064
# Epoch 684/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.2997 - score: 6.6508 - val_loss: 49.9355 - val_score: 6.6734
# Epoch 685/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.3870 - score: 6.6558 - val_loss: 51.2156 - val_score: 6.7003
# Epoch 686/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.1107 - score: 6.6471 - val_loss: 49.8598 - val_score: 6.6720
# Epoch 687/700
# 6/6 [==============================] - 0s 10ms/step - loss: 50.0409 - score: 6.6378 - val_loss: 51.6119 - val_score: 6.7105
# Epoch 688/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.4692 - score: 6.6488 - val_loss: 50.0960 - val_score: 6.6761
# Epoch 689/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.1877 - score: 6.6442 - val_loss: 50.2709 - val_score: 6.6808
# Epoch 690/700
# 6/6 [==============================] - 0s 8ms/step - loss: 49.9677 - score: 6.6318 - val_loss: 50.2277 - val_score: 6.6779
# Epoch 691/700
# 6/6 [==============================] - 0s 9ms/step - loss: 49.9872 - score: 6.6354 - val_loss: 50.4094 - val_score: 6.6815
# Epoch 692/700
# 6/6 [==============================] - 0s 9ms/step - loss: 49.9310 - score: 6.6368 - val_loss: 50.1592 - val_score: 6.6783
# Epoch 693/700
# 6/6 [==============================] - 0s 9ms/step - loss: 49.9759 - score: 6.6343 - val_loss: 50.4551 - val_score: 6.6854
# Epoch 694/700
# 6/6 [==============================] - 0s 8ms/step - loss: 49.9433 - score: 6.6351 - val_loss: 50.2490 - val_score: 6.6810
# Epoch 695/700
# 6/6 [==============================] - 0s 9ms/step - loss: 49.9350 - score: 6.6332 - val_loss: 50.4929 - val_score: 6.6879
# Epoch 696/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0274 - score: 6.6347 - val_loss: 50.7300 - val_score: 6.6923
# Epoch 697/700
# 6/6 [==============================] - 0s 10ms/step - loss: 50.0823 - score: 6.6430 - val_loss: 50.1076 - val_score: 6.6753
# Epoch 698/700
# 6/6 [==============================] - 0s 8ms/step - loss: 49.9852 - score: 6.6417 - val_loss: 50.8184 - val_score: 6.6919
# Epoch 699/700
# 6/6 [==============================] - 0s 9ms/step - loss: 50.0968 - score: 6.6411 - val_loss: 49.8561 - val_score: 6.6725
# Epoch 700/700
# 6/6 [==============================] - 0s 8ms/step - loss: 50.0372 - score: 6.6287 - val_loss: 51.2391 - val_score: 6.7039
# train [50.14681625366211, 6.638415813446045]
# val [51.23912811279297, 6.703920364379883]
# predict val...
# predict test...
# CPU times: user 1min 31s, sys: 6.63 s, total: 1min 38s
# Wall time: 1min 28s

# %%
pred

# %%
sigma_opt = mean_absolute_error(y, pred[:, 1])
unc = pred[:,2] - pred[:, 0]
sigma_mean = np.mean(unc)
print(sigma_opt, sigma_mean)

# %%
idxs = np.random.randint(0, y.shape[0], 100)
plt.plot(y[idxs], label="ground truth")
plt.plot(pred[idxs, 0], label="q25")
plt.plot(pred[idxs, 1], label="q50")
plt.plot(pred[idxs, 2], label="q75")
plt.legend(loc="best")
plt.show()

# %%
print(unc.min(), unc.mean(), unc.max(), (unc>=0).mean())

# %%
plt.hist(unc)
plt.title("uncertainty in prediction")
plt.show()

# %%
sub.head()

# %%
# PREDICTION
sub['FVC1'] = 1.*pe[:, 1]
sub['Confidence1'] = pe[:, 2] - pe[:, 0]
subm = sub[['Patient_Week','FVC','Confidence','FVC1','Confidence1']].copy()
yo=subm.loc[~subm.FVC1.isnull()]
subm.loc[~subm.FVC1.isnull()].head()

# %%
subm.loc[~subm.FVC1.isnull(),'FVC'] = subm.loc[~subm.FVC1.isnull(),'FVC1']
sigma_mean = 60
if sigma_mean<sigma_mean:
    subm['Confidence'] = sigma_opt
else:
    subm.loc[~subm.FVC1.isnull(),'Confidence'] = subm.loc[~subm.FVC1.isnull(),'Confidence1']

# %%
subm.head()

# %%
subm.describe().T

# %%
otest = pd.read_csv('../input/osic-pulmonary-fibrosis-progression/test.csv')
for i in range(len(otest)):
    subm.loc[subm['Patient_Week']==otest.Patient[i]+'_'+str(otest.Weeks[i]), 'FVC'] = otest.FVC[i]
    subm.loc[subm['Patient_Week']==otest.Patient[i]+'_'+str(otest.Weeks[i]), 'Confidence'] = 0.1

# %%
subm[["Patient_Week","FVC","Confidence"]].to_csv("submission_regression.csv", index=False)

# %%
reg_sub = subm[["Patient_Week","FVC","Confidence"]].copy()

# %%
reg_sub

# %% [markdown]
# # Ensemble (Simple Blend)

# %%
df1 = img_sub.sort_values(by=['Patient_Week'], ascending=True).reset_index(drop=True)
df2 = reg_sub.sort_values(by=['Patient_Week'], ascending=True).reset_index(drop=True)

# %%
df1

# %%
actual=yo[['Patient_Week','FVC']]

# %%
main=actual.sort_values(by=['Patient_Week'], ascending=True).reset_index(drop=True)

# %%
main

# %%
df = df1[['Patient_Week']].copy()
df['FVC'] = (0.45*df1['FVC'] + 0.55*df2['FVC'])
df['Confidence'] = (0.45*df1['Confidence'] + 0.55*df2['Confidence'])
df

# %%
df.to_csv('submission.csv', index=False)

# %%
df.Confidence

# %%
def mainscore(actual_fvc, predicted_fvc, confidence, return_values = False):
    sd_clipped = np.maximum(confidence, 70)
    delta = np.minimum(np.abs(actual_fvc - predicted_fvc), 1000)
    metric = - np.sqrt(2) * delta / sd_clipped - np.log(np.sqrt(2) * sd_clipped)

    if return_values:
        return metric
    else:
        return np.mean(metric)

# %%
x=mainscore(main['FVC'],df['FVC'],df.Confidence)

# %%
x
